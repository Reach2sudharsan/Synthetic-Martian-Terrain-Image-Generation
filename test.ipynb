# %%
import pandas as pd

# %%
syn_5_data = pd.read_csv("../Synthetic-Martian-Terrain-Image-Generation/runs/detect/train/results.csv")
syn_50_data = pd.read_csv("../Synthetic-Martian-Terrain-Image-Generation/runs/detect/train5/results.csv")

# %%
syn_5_data
# Out:
#      epoch       time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0        1    114.997         2.21804         3.13207         1.83436
# 1        2    227.584         2.17519         2.91841         1.77727
# 2        3    340.063         2.22573         2.90819         1.77303
# 3        4    450.813         2.21686         2.89972         1.81004
# 4        5    560.787         2.13763         2.80540         1.73916
# ..     ...        ...             ...             ...             ...
# 195    196  22326.400         1.25545         1.16937         1.21300
# 196    197  22436.400         1.28041         1.19270         1.22138
# 197    198  22546.100         1.25488         1.14129         1.22047
# 198    199  22656.000         1.25804         1.16027         1.20560
# 199    200  22766.300         1.27453         1.16161         1.21602
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                 0.12055            0.05352           0.03646
# 1                 0.10713            0.08104           0.04517
# 2                 0.10049            0.09021           0.04107
# 3                 0.03910            0.07645           0.02516
# 4                 0.13446            0.09786           0.05267
# ..                    ...                ...               ...
# 195               0.70452            0.36850           0.44854
# 196               0.68606            0.38226           0.44856
# 197               0.65695            0.38226           0.44781
# 198               0.66370            0.37419           0.44784
# 199               0.61980            0.39450           0.44971
#
#      metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0                0.01567       2.48400       4.57704       2.05182  0.000661
# 1                0.02043       2.51836       4.33140       1.90061  0.001321
# 2                0.01546       2.57743       5.20973       2.02921  0.001974
# 3                0.01135       2.48936       7.36917       2.08445  0.001970
# 4                0.02302       2.36901       4.00948       1.82324  0.001960
# ..                   ...           ...           ...           ...       ...
# 195              0.22558       1.79363       2.23866       1.51844  0.000069
# 196              0.22495       1.77254       2.26883       1.51317  0.000060
# 197              0.22429       1.76081       2.31151       1.51570  0.000050
# 198              0.22579       1.74009       2.28554       1.49835  0.000040
# 199              0.22695       1.73190       2.29363       1.49535  0.000030
#
#        lr/pg1    lr/pg2
# 0    0.000661  0.000661
# 1    0.001321  0.001321
# 2    0.001974  0.001974
# 3    0.001970  0.001970
# 4    0.001960  0.001960
# ..        ...       ...
# 195  0.000069  0.000069
# 196  0.000060  0.000060
# 197  0.000050  0.000050
# 198  0.000040  0.000040
# 199  0.000030  0.000030
#
# [200 rows x 15 columns]

# %%
syn_50_data
# Out:
#      epoch       time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0        1    12.9398         1.79661         2.82990         1.68436
# 1        2    21.4366         1.86210         2.60306         1.75124
# 2        3    29.7126         1.88362         2.53629         1.72960
# 3        4    37.9740         1.91335         2.53104         1.76990
# 4        5    46.2902         1.86652         2.46591         1.75985
# ..     ...        ...             ...             ...             ...
# 195    196  2019.6600         0.96909         0.89580         1.13364
# 196    197  2028.0000         0.92788         0.87593         1.12097
# 197    198  2036.2400         0.97122         0.90395         1.14086
# 198    199  2044.5900         0.89996         0.84454         1.10666
# 199    200  2052.9800         0.95300         0.86744         1.11824
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                 0.09647            0.03152           0.01836
# 1                 0.10283            0.03503           0.01996
# 2                 0.06224            0.04729           0.01649
# 3                 0.12111            0.05079           0.02078
# 4                 0.08008            0.08406           0.02972
# ..                    ...                ...               ...
# 195               0.41933            0.27320           0.25887
# 196               0.45408            0.24694           0.24994
# 197               0.41265            0.24518           0.24088
# 198               0.45806            0.25164           0.25771
# 199               0.49786            0.24136           0.25996
#
#      metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0                0.00889       2.61102       3.28846       2.00958  0.000661
# 1                0.00866       2.44927       3.14551       1.86718  0.001321
# 2                0.00670       2.47751       4.07942       2.04481  0.001974
# 3                0.00674       2.45622       5.32888       2.02753  0.001970
# 4                0.01256       2.37973       3.55372       2.01139  0.001960
# ..                   ...           ...           ...           ...       ...
# 195              0.12473       1.71324       1.67287       1.38346  0.000069
# 196              0.12234       1.72008       1.68095       1.39202  0.000060
# 197              0.11786       1.71370       1.70797       1.38457  0.000050
# 198              0.12486       1.70451       1.67310       1.38010  0.000040
# 199              0.12706       1.70963       1.67596       1.38547  0.000030
#
#        lr/pg1    lr/pg2
# 0    0.000661  0.000661
# 1    0.001321  0.001321
# 2    0.001974  0.001974
# 3    0.001970  0.001970
# 4    0.001960  0.001960
# ..        ...       ...
# 195  0.000069  0.000069
# 196  0.000060  0.000060
# 197  0.000050  0.000050
# 198  0.000040  0.000040
# 199  0.000030  0.000030
#
# [200 rows x 15 columns]

# %%
syn_5_data.columns
# Out:
# Index(['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss',
#        'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)',
#        'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss',
#        'lr/pg0', 'lr/pg1', 'lr/pg2'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np

def summarize_metrics(df, label, start_epoch=None, end_epoch=None):
    """Summarize key metrics from YOLO training logs."""
    if start_epoch is not None and end_epoch is not None:
        df = df[(df['epoch'] >= start_epoch) & (df['epoch'] <= end_epoch)]

    return pd.DataFrame([{
        "Label": label,
        "Mean Train Box Loss": df["train/box_loss"].mean(),
        "Mean Train Cls Loss": df["train/cls_loss"].mean(),
        "Mean Train DFL Loss": df["train/dfl_loss"].mean(),
        "Mean Val Box Loss": df["val/box_loss"].mean(),
        "Mean Val Cls Loss": df["val/cls_loss"].mean(),
        "Mean Val DFL Loss": df["val/dfl_loss"].mean(),
        "Mean mAP50": df["metrics/mAP50(B)"].mean(),
        "Mean mAP50-95": df["metrics/mAP50-95(B)"].mean(),
        "Max mAP50": df["metrics/mAP50(B)"].max(),
        "Min mAP50": df["metrics/mAP50(B)"].min(),
    }])

# %%
# Summary over all epochs
full_summary = pd.concat([
    summarize_metrics(syn_5_data, "syn_5"),
    summarize_metrics(syn_50_data, "syn_50")
], ignore_index=True)

# Summary over epochs 45–50
summary = pd.concat([
    summarize_metrics(syn_5_data, "syn_5 (Epochs 180-200)", 180, 200),
    summarize_metrics(syn_50_data, "syn_50 (Epochs 180–200)", 180, 200)
], ignore_index=True)

print("Full Epoch Summary")
print(full_summary.to_string(index=False))

print("Summary from Epochs 180–200")
print(summary.to_string(index=False))
# Out:
# Full Epoch Summary
#  Label  Mean Train Box Loss  Mean Train Cls Loss  Mean Train DFL Loss  Mean Val Box Loss  Mean Val Cls Loss  Mean Val DFL Loss  Mean mAP50  Mean mAP50-95  Max mAP50  Min mAP50
#  syn_5             1.588255             1.823802             1.387604           1.985437           2.706403           1.605332    0.286029       0.136016    0.45028    0.02516
# syn_50             1.258633             1.455331             1.322221           1.901961           2.188074           1.527708    0.167844       0.077356    0.30139    0.01649
# Summary from Epochs 180–200
#                   Label  Mean Train Box Loss  Mean Train Cls Loss  Mean Train DFL Loss  Mean Val Box Loss  Mean Val Cls Loss  Mean Val DFL Loss  Mean mAP50  Mean mAP50-95  Max mAP50  Min mAP50
#  syn_5 (Epochs 180-200)             1.304698             1.251339             1.223295           1.794760           2.231802           1.514563    0.443077       0.222916    0.45028    0.42858
# syn_50 (Epochs 180–200)             0.986258             0.960449             1.148281           1.731994           1.704774           1.397373    0.245249       0.117900    0.27634    0.18814

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
plt.figure(figsize=(12, 6))
plt.plot(syn_5_data['epoch'], syn_5_data['metrics/mAP50(B)'], label='syn_5 mAP50', color='blue')
plt.plot(syn_50_data['epoch'], syn_50_data['metrics/mAP50(B)'], label='syn_50 mAP50', color='green')
plt.title('mAP50 Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('mAP50')
plt.legend()
plt.grid(True)
plt.show()
sns.reset_orig()
